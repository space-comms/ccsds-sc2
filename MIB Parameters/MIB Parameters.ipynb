# %%
""" MIB Parameters """

# Acquisition Idle duration
# Time that shall be used to radiate the idle sequence pattern after carrier only to enable the receiving transceiver to achieve symbol synchronization and decoder lock
# Out:
#   Cell In[2], line 3
#     local spacecraft ID
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# MIB parameters for data service operations
# 1. acquisition idle duration
# 2. carrier loss timer duration
# 3. carrier only duration
# 4. comm change lifetime
# 5. comm change notification
# 6. comm change response
# 7. comm change waiting period
# 8. hail lifetime
# 9. hail notification
# 10. hail response
# 11. hail wait duration
# 12. hailing channel
# 13. hailing data rate
# 14. hailing symbol rate
# 15. interval clock
# 16. link SNR step
# 17. local PCID
# 18. local spacecraft ID
# 19. maximum failed token passes
# 20. frame version in use
# 21. maximum frame length
# 22. maximum packet size
# 23. persistence wait time
# 24. plcw repeat interval
# 25. receive duration
# 26. drop carrier duration
# 27. remote pcid
# 28. remote spacecraft ID
# 29. resync local
# 30. resync lifetime
# 31. resync notification
# 32. resync response
# 33. resync waiting period
# 34. send duration
# 35. source destination ID
# 36. synch timeout
# 37. tail idle duration
# 38. test source
# 39. transmission window
#
#
# 1. local spacecraft ID
# 2. test source
# 3. carrier only duration
# 4. acquisition idle duration
# 5. tail idle duration
# 6. carrier loss time duration
# 7. comm change waiting period
# 8. comm change response
# 9. comm change notification
# 10. comm change lifetime
# 11. hail wait duration
# 12. hail response
# 13. hail notification
# 14. hail lifetime
# 15. hailing data rate/ hailing symbol rate
# 16. send duration
# 17. receive duration
# 18. plcw repeat interval
