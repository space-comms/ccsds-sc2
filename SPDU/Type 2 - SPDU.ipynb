# %%
# Time Distribution PDU

DIRECTIVE_TYPE_MAP = {
    0x00: "NULL",
    0x01: "TIME_TRANSFER"


}
class SPDU2

    # directive type
    if type = 0000 0000:
        type = null
    # transceiver clock
    # send side delay
    # one-way-light-time
    def __init__(self):
